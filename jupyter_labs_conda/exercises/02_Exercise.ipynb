# %% [markdown]
# # Exercise #2

# %% [markdown]
# Step 1. Use the Python Standard Library to read the currency data for 2020 from the "eurofxref-hist.csv".

# %%
# Step 1 Solution

import csv

data = []

with open("data/eurofxref-hist.csv") as csv_file:
    csv_reader = csv.reader(csv_file)
    
    next(csv_reader)
    
    for row in csv_reader:
        data.append(row)
        
print(data[:5])
# Out:
# [['2021-04-09', '1.1888', '130.42', '1.9558', 'N/A', '25.945', '7.4372', 'N/A', '0.86658', '357.97', 'N/A', 'N/A', 'N/A', '4.5392', 'N/A', '4.9198', '10.1725', 'N/A', 'N/A', '1.101', '151.9', '10.113', '7.5755', '91.8152', 'N/A', '9.6903', '1.5579', '6.6641', '1.495', '7.7934', '9.247', '17354.52', '3.9093', '88.8145', '1331.28', '23.9374', '4.9157', '1.686', '57.764', '1.5941', '37.388', '17.31', ''], ['2021-04-08', '1.1873', '129.71', '1.9558', 'N/A', '25.875', '7.4377', 'N/A', '0.8629', '358.65', 'N/A', 'N/A', 'N/A', '4.5513', 'N/A', '4.9198', '10.2073', 'N/A', 'N/A', '1.1021', '151', '10.078', '7.5835', '91.4618', 'N/A', '9.6799', '1.5539', '6.6545', '1.4947', '7.7749', '9.2356', '17257.41', '3.8994', '88.5885', '1324.91', '23.9497', '4.9125', '1.6855', '57.713', '1.5916', '37.347', '17.2677', ''], ['2021-04-07', '1.1884', '130.56', '1.9558', 'N/A', '25.919', '7.4365', 'N/A', '0.86065', '359.68', 'N/A', 'N/A', 'N/A', '4.5756', 'N/A', '4.9185', '10.236', 'N/A', 'N/A', '1.1044', '150.4', '10.0535', '7.5763', '92.3359', 'N/A', '9.7227', '1.5581', '6.644', '1.4982', '7.7761', '9.2527', '17304.71', '3.9236', '88.3675', '1328.05', '24.0091', '4.9099', '1.6907', '57.965', '1.5917', '37.286', '17.2803', ''], ['2021-04-06', '1.1812', '130.27', '1.9558', 'N/A', '26.051', '7.4379', 'N/A', '0.85358', '360.31', 'N/A', 'N/A', 'N/A', '4.5914', 'N/A', '4.9175', '10.261', 'N/A', 'N/A', '1.107', '149.5', '10.0768', '7.57', '90.5074', 'N/A', '9.6281', '1.5482', '6.6644', '1.484', '7.739', '9.186', '17133.31', '3.9005', '86.7', '1323.16', '23.9395', '4.8801', '1.6814', '57.424', '1.584', '37.054', '17.1399', ''], ['2021-04-01', '1.1746', '130.03', '1.9558', 'N/A', '26.085', '7.4379', 'N/A', '0.85195', '361.84', 'N/A', 'N/A', 'N/A', '4.6089', 'N/A', '4.9088', '10.2753', 'N/A', 'N/A', '1.1099', '148.7', '10.0408', '7.5705', '89.5944', 'N/A', '9.5903', '1.55', '6.6149', '1.4787', '7.7195', '9.1346', '17068.23', '3.915', '86.2275', '1328.36', '23.8792', '4.8693', '1.6806', '57.076', '1.5801', '36.73', '17.2074', '']]

# %% [markdown]
# Step 2. Create a new NumPy Array from the loaded currency data. The array should only contain the following columns: USD, CAD, JPY, and the RUB.

# %%
# Step 2 Solution

import numpy as np

rates = []

for row in data:
    
    if (row[0].startswith('2020')):
        rates.append([ float(row[1]), float(row[28]), float(row[2]), float(row[23]) ])

rates = np.array(rates)

print(rates.shape)
print(rates.size)
print(len(rates))
# Out:
# (257, 4)
# 1028
# 257

# %% [markdown]
# Step 3. Add a new column for EUR data. Initialized each element with a 1. Display the new array with the USD, CAD, JPY, RUB, and EUR columns.

# %%
# Step 3 Solution

eur_rates = np.ones((rates.shape[0],1))

all_rates = np.column_stack([ eur_rates, rates ])
# all_rates = np.stack([ eur_rates, rates ], axis=1)

print(all_rates.shape)
print(all_rates[0])
# Out:
# (257, 5)
# [  1.       1.2271   1.5633 126.49    91.4671]

# %% [markdown]
# Step 4. The currency rates are all calculated with respect to the EUR. Update the rates to be calculated with respect to the USD. For each currency column on each row, divide each currency by the value for the USD. Display the array.

# %%
# Step 4 Solution

# for row_index in range(all_rates.shape[0]):
#     all_rates[row_index] = all_rates[row_index] / all_rates[row_index,1]
    
all_rates = all_rates / all_rates[:, 1, None]

# [                              
#                                  [
#  [ 1, 1.22, 1.45, 23, 45 ]    /    [1.22]
#  [ 1, 1.23, 1.45, 24, 45 ]    /    [1.23]
#                                 ]
# ]

print(all_rates.shape)
print(all_rates[0])
# Out:
# [[1.2271]
#  [1.2281]
#  [1.2259]
#  [1.2219]
#  [1.2193]
#  [1.2166]
#  [1.2239]
#  [1.2173]
#  [1.2259]
#  [1.2246]
#  [1.2189]
#  [1.214 ]
#  [1.2162]
#  [1.2127]
#  [1.2115]
#  [1.2109]
#  [1.2114]
#  [1.2128]
#  [1.2159]
#  [1.2151]
#  [1.2066]
#  [1.1968]
#  [1.198 ]
#  [1.1922]
#  [1.19  ]
#  [1.189 ]
#  [1.1865]
#  [1.1901]
#  [1.1863]
#  [1.1832]
#  [1.1868]
#  [1.1882]
#  [1.183 ]
#  [1.1815]
#  [1.1791]
#  [1.1766]
#  [1.1808]
#  [1.1883]
#  [1.187 ]
#  [1.1855]
#  [1.1721]
#  [1.1702]
#  [1.1652]
#  [1.1698]
#  [1.1704]
#  [1.1727]
#  [1.1832]
#  [1.1819]
#  [1.1856]
#  [1.1821]
#  [1.1852]
#  [1.181 ]
#  [1.1785]
#  [1.1741]
#  [1.1698]
#  [1.175 ]
#  [1.1787]
#  [1.1799]
#  [1.1795]
#  [1.1765]
#  [1.177 ]
#  [1.1795]
#  [1.1768]
#  [1.173 ]
#  [1.1752]
#  [1.1708]
#  [1.1702]
#  [1.167 ]
#  [1.1634]
#  [1.1645]
#  [1.1692]
#  [1.174 ]
#  [1.1787]
#  [1.1833]
#  [1.1797]
#  [1.1869]
#  [1.1892]
#  [1.1876]
#  [1.1854]
#  [1.1849]
#  [1.1773]
#  [1.1785]
#  [1.1824]
#  [1.1842]
#  [1.1813]
#  [1.1861]
#  [1.1987]
#  [1.194 ]
#  [1.1915]
#  [1.1806]
#  [1.1789]
#  [1.1814]
#  [1.1847]
#  [1.1769]
#  [1.185 ]
#  [1.1933]
#  [1.1906]
#  [1.1853]
#  [1.1813]
#  [1.1833]
#  [1.1771]
#  [1.1783]
#  [1.1763]
#  [1.1817]
#  [1.1843]
#  [1.1854]
#  [1.1765]
#  [1.1726]
#  [1.1848]
#  [1.1743]
#  [1.1725]
#  [1.1717]
#  [1.176 ]
#  [1.1608]
#  [1.1569]
#  [1.1578]
#  [1.1443]
#  [1.1448]
#  [1.1428]
#  [1.1414]
#  [1.1444]
#  [1.1375]
#  [1.1329]
#  [1.1276]
#  [1.1342]
#  [1.1286]
#  [1.129 ]
#  [1.1325]
#  [1.1224]
#  [1.1286]
#  [1.12  ]
#  [1.1198]
#  [1.1284]
#  [1.1213]
#  [1.12  ]
#  [1.128 ]
#  [1.1318]
#  [1.1213]
#  [1.121 ]
#  [1.1222]
#  [1.1232]
#  [1.1308]
#  [1.1253]
#  [1.1304]
#  [1.1348]
#  [1.1375]
#  [1.1294]
#  [1.1285]
#  [1.133 ]
#  [1.125 ]
#  [1.1194]
#  [1.1174]
#  [1.1116]
#  [1.1136]
#  [1.1016]
#  [1.0991]
#  [1.0975]
#  [1.091 ]
#  [1.0904]
#  [1.1   ]
#  [1.0958]
#  [1.095 ]
#  [1.0832]
#  [1.0798]
#  [1.0792]
#  [1.0875]
#  [1.0858]
#  [1.0824]
#  [1.0843]
#  [1.0783]
#  [1.0807]
#  [1.0843]
#  [1.0942]
#  [1.0876]
#  [1.0842]
#  [1.0877]
#  [1.0852]
#  [1.08  ]
#  [1.0772]
#  [1.0867]
#  [1.0837]
#  [1.086 ]
#  [1.086 ]
#  [1.0888]
#  [1.0903]
#  [1.0963]
#  [1.0867]
#  [1.0871]
#  [1.0885]
#  [1.0791]
#  [1.0785]
#  [1.0906]
#  [1.0936]
#  [1.0956]
#  [1.1034]
#  [1.0977]
#  [1.0981]
#  [1.0827]
#  [1.0843]
#  [1.0783]
#  [1.0707]
#  [1.0801]
#  [1.0934]
#  [1.0982]
#  [1.1157]
#  [1.1104]
#  [1.124 ]
#  [1.1336]
#  [1.139 ]
#  [1.1456]
#  [1.1336]
#  [1.1187]
#  [1.1125]
#  [1.1117]
#  [1.1122]
#  [1.0977]
#  [1.0964]
#  [1.0875]
#  [1.084 ]
#  [1.0818]
#  [1.0801]
#  [1.079 ]
#  [1.08  ]
#  [1.0816]
#  [1.0835]
#  [1.0842]
#  [1.0867]
#  [1.0914]
#  [1.0901]
#  [1.0951]
#  [1.0969]
#  [1.1003]
#  [1.1023]
#  [1.1048]
#  [1.1066]
#  [1.1052]
#  [1.1029]
#  [1.1001]
#  [1.1005]
#  [1.1025]
#  [1.1035]
#  [1.1091]
#  [1.1088]
#  [1.1115]
#  [1.1085]
#  [1.1108]
#  [1.1169]
#  [1.1142]
#  [1.1115]
#  [1.1126]
#  [1.1091]
#  [1.111 ]
#  [1.1115]
#  [1.1172]
#  [1.1194]
#  [1.1147]
#  [1.1193]]
# (257, 5)
# [  0.81492951   1.           1.2739793  103.08043354  74.53923886]

# %% [markdown]
# Step 5. For the EUR, what was the max and min value for 2020? What was the max and min value for the RUB?

# %%
# Step 5 Solution

print(all_rates[:,0].min())
print(all_rates[:,0].max())
print(np.min(all_rates[:,0]))
print(np.max(all_rates[:,0]))
# Out:
# 0.814265939255761
# 0.933968431867003
# 0.814265939255761
# 0.933968431867003

# %% [markdown]
# Step 6. Plot the price of the EUR, CAD, USD, and JPY for each "day". The date should be represented on the X-axis, and price of the currency on the Y-axis.

# %%
# Step 6 Solution

from matplotlib import pyplot as plt

# %matplotlib inline

plt.plot(all_rates[:,0], label="EUR", color="blue")
plt.plot(all_rates[:,1], label="USD", color="green")
plt.plot(all_rates[:,2], label="CAD", color="orange")
# plt.plot(all_rates[:,3], label="JPY", color="purple")
# plt.plot(all_rates[:,4], label="RUB", color="red")

plt.title('Currency Rates by Day in 2020')
plt.xlabel('Day of the Year')
plt.ylabel('Rate')
plt.legend(loc='center right')

plt.show()
